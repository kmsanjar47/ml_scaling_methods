# %%
# !pip install scikit-learn

# %% [markdown]
# <h1>DataFrame Creation</h1>

# %%
import pandas as pd
import numpy as np

# %%
data = {"price":[110,105,115,120,110,130,150,100,105]}
df = pd.DataFrame(data)

# %%
df
# Out:
#    price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110
# 5    130
# 6    150
# 7    100
# 8    105

# %% [markdown]
# <h1>Normalization</h1>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
df["min_max_scaled_data"] = scaler.fit_transform(df[["price"]])

# %%
df
# Out:
#    price  min_max_scaled_data
# 0    110                  0.2
# 1    105                  0.1
# 2    115                  0.3
# 3    120                  0.4
# 4    110                  0.2
# 5    130                  0.6
# 6    150                  1.0
# 7    100                  0.0
# 8    105                  0.1

# %% [markdown]
# <h1>Standardization</h1>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df["standard_scaled_data"] = scaler.fit_transform(df[["price"]])

# %%
df
# Out:
#    price  min_max_scaled_data  standard_scaled_data
# 0    110                  0.2             -0.416356
# 1    105                  0.1             -0.757011
# 2    115                  0.3             -0.075701
# 3    120                  0.4              0.264954
# 4    110                  0.2             -0.416356
# 5    130                  0.6              0.946264
# 6    150                  1.0              2.308884
# 7    100                  0.0             -1.097666
# 8    105                  0.1             -0.757011

# %% [markdown]
# <h1>Log Transform</h1>

# %%
df["log_transformed_data"] = np.log1p(df[["price"]])

# %%
df
# Out:
#    price  min_max_scaled_data  standard_scaled_data  log_transformed_data
# 0    110                  0.2             -0.416356              4.709530
# 1    105                  0.1             -0.757011              4.663439
# 2    115                  0.3             -0.075701              4.753590
# 3    120                  0.4              0.264954              4.795791
# 4    110                  0.2             -0.416356              4.709530
# 5    130                  0.6              0.946264              4.875197
# 6    150                  1.0              2.308884              5.017280
# 7    100                  0.0             -1.097666              4.615121
# 8    105                  0.1             -0.757011              4.663439

# %%
# from scipy.stats import boxcox

# %%
# df = pd.DataFrame(data)

# %%
# df["transformed_data"] = boxcox(df["price"]+1)

# %% [markdown]
# <h1>Max Absolute Scaler</h1>

# %%
from sklearn.preprocessing import MaxAbsScaler

# %%
scaler = MaxAbsScaler()
df["max_abs_scaled_data"] = scaler.fit_transform(df[["price"]])

# %%
df
# Out:
#    price  min_max_scaled_data  standard_scaled_data  log_transformed_data  \
# 0    110                  0.2             -0.416356              4.709530
# 1    105                  0.1             -0.757011              4.663439
# 2    115                  0.3             -0.075701              4.753590
# 3    120                  0.4              0.264954              4.795791
# 4    110                  0.2             -0.416356              4.709530
# 5    130                  0.6              0.946264              4.875197
# 6    150                  1.0              2.308884              5.017280
# 7    100                  0.0             -1.097666              4.615121
# 8    105                  0.1             -0.757011              4.663439
#
#    max_abs_scaled_data
# 0             0.733333
# 1             0.700000
# 2             0.766667
# 3             0.800000
# 4             0.733333
# 5             0.866667
# 6             1.000000
# 7             0.666667
# 8             0.700000

# %% [markdown]
# <h1>Robust Scaler</h1>

# %%
from sklearn.preprocessing import RobustScaler

# %%
scaler = RobustScaler()
df["robust_scaled_data"] = scaler.fit_transform(df[["price"]])

# %%
df
# Out:
#    price  min_max_scaled_data  standard_scaled_data  log_transformed_data  \
# 0    110                  0.2             -0.416356              4.709530
# 1    105                  0.1             -0.757011              4.663439
# 2    115                  0.3             -0.075701              4.753590
# 3    120                  0.4              0.264954              4.795791
# 4    110                  0.2             -0.416356              4.709530
# 5    130                  0.6              0.946264              4.875197
# 6    150                  1.0              2.308884              5.017280
# 7    100                  0.0             -1.097666              4.615121
# 8    105                  0.1             -0.757011              4.663439
#
#    max_abs_scaled_data  robust_scaled_data
# 0             0.733333            0.000000
# 1             0.700000           -0.333333
# 2             0.766667            0.333333
# 3             0.800000            0.666667
# 4             0.733333            0.000000
# 5             0.866667            1.333333
# 6             1.000000            2.666667
# 7             0.666667           -0.666667
# 8             0.700000           -0.333333

# %% [markdown]
# <h1>Excel File Generation</h1>

# %%
# !pip install openpyxl

# %%
df.to_excel("ml_scaled_data.xlsx", index=False)
